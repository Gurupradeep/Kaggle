# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['train_V2.csv', 'test_V2.csv', 'sample_submission_V2.csv']

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import os
from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display

from sklearn import metrics
from sklearn_pandas import DataFrameMapper
from sklearn.preprocessing import LabelEncoder, Imputer, StandardScaler
from pandas.api.types import is_string_dtype, is_numeric_dtype
from sklearn.ensemble import forest
from sklearn.tree import export_graphviz
import IPython, graphviz, re

# %% [markdown]
# # **Helper functions**

# %%
def draw_tree(t, df, size=10, ratio=0.6, precision=0):
    """ Draws a representation of a random forest in IPython.

    Parameters:
    -----------
    t: The tree you wish to draw
    df: The data used to train the tree. This is used to get the names of the features.
    """
    s=export_graphviz(t, out_file=None, feature_names=df.columns, filled=True,
                      special_characters=True, rotate=True, precision=precision)
    IPython.display.display(graphviz.Source(re.sub('Tree {',
       f'Tree {{ size={size}; ratio={ratio}', s)))

# %%
def get_sample(df,n):
    """ Gets a random sample of n rows from df, without replacement.

    Parameters:
    -----------
    df: A pandas data frame, that you wish to sample from.
    n: The number of rows you wish to sample.

    Returns:
    --------
    return value: A random sample of n rows of df.

    Examples:
    ---------
    >>> df = pd.DataFrame({'col1' : [1, 2, 3], 'col2' : ['a', 'b', 'a']})
    >>> df
       col1 col2
    0     1    a
    1     2    b
    2     3    a

    >>> get_sample(df, 2)
       col1 col2
    1     2    b
    2     3    a
    """
    idxs = sorted(np.random.permutation(len(df))[:n])
    return df.iloc[idxs].copy()

# %%
def train_cats(df):
    """Change any columns of strings in a panda's dataframe to a column of
    categorical values. This applies the changes inplace.

    Parameters:
    -----------
    df: A pandas dataframe. Any columns of strings will be changed to
        categorical values.

    Examples:
    ---------

    >>> df = pd.DataFrame({'col1' : [1, 2, 3], 'col2' : ['a', 'b', 'a']})
    >>> df
       col1 col2
    0     1    a
    1     2    b
    2     3    a

    note the type of col2 is string

    >>> train_cats(df)
    >>> df

       col1 col2
    0     1    a
    1     2    b
    2     3    a

    now the type of col2 is category
    """
    for n,c in df.items():
        if is_string_dtype(c): df[n] = c.astype('category').cat.as_ordered()

def apply_cats(df, trn):
    """Changes any columns of strings in df into categorical variables using trn as
    a template for the category codes.

    Parameters:
    -----------
    df: A pandas dataframe. Any columns of strings will be changed to
        categorical values. The category codes are determined by trn.

    trn: A pandas dataframe. When creating a category for df, it looks up the
        what the category's code were in trn and makes those the category codes
        for df.

    Examples:
    ---------
    >>> df = pd.DataFrame({'col1' : [1, 2, 3], 'col2' : ['a', 'b', 'a']})
    >>> df
       col1 col2
    0     1    a
    1     2    b
    2     3    a

    note the type of col2 is string

    >>> train_cats(df)
    >>> df

       col1 col2
    0     1    a
    1     2    b
    2     3    a

    now the type of col2 is category {a : 1, b : 2}

    >>> df2 = pd.DataFrame({'col1' : [1, 2, 3], 'col2' : ['b', 'a', 'a']})
    >>> apply_cats(df2, df)

           col1 col2
        0     1    b
        1     2    a
        2     3    a

    now the type of col is category {a : 1, b : 2}
    """
    for n,c in df.items():
        if (n in trn.columns) and (trn[n].dtype.name=='category'):
            df[n] = c.astype('category').cat.as_ordered()
            df[n].cat.set_categories(trn[n].cat.categories, ordered=True, inplace=True)

def fix_missing(df, col, name, na_dict):
    """ Fill missing data in a column of df with the median, and add a {name}_na column
    which specifies if the data was missing.

    Parameters:
    -----------
    df: The data frame that will be changed.

    col: The column of data to fix by filling in missing data.

    name: The name of the new filled column in df.

    na_dict: A dictionary of values to create na's of and the value to insert. If
        name is not a key of na_dict the median will fill any missing data. Also
        if name is not a key of na_dict and there is no missing data in col, then
        no {name}_na column is not created.


    Examples:
    ---------
    >>> df = pd.DataFrame({'col1' : [1, np.NaN, 3], 'col2' : [5, 2, 2]})
    >>> df
       col1 col2
    0     1    5
    1   nan    2
    2     3    2

    >>> fix_missing(df, df['col1'], 'col1', {})
    >>> df
       col1 col2 col1_na
    0     1    5   False
    1     2    2    True
    2     3    2   False


    >>> df = pd.DataFrame({'col1' : [1, np.NaN, 3], 'col2' : [5, 2, 2]})
    >>> df
       col1 col2
    0     1    5
    1   nan    2
    2     3    2

    >>> fix_missing(df, df['col2'], 'col2', {})
    >>> df
       col1 col2
    0     1    5
    1   nan    2
    2     3    2


    >>> df = pd.DataFrame({'col1' : [1, np.NaN, 3], 'col2' : [5, 2, 2]})
    >>> df
       col1 col2
    0     1    5
    1   nan    2
    2     3    2

    >>> fix_missing(df, df['col1'], 'col1', {'col1' : 500})
    >>> df
       col1 col2 col1_na
    0     1    5   False
    1   500    2    True
    2     3    2   False
    """
    if is_numeric_dtype(col):
        if pd.isnull(col).sum() or (name in na_dict):
            df[name+'_na'] = pd.isnull(col)
            filler = na_dict[name] if name in na_dict else col.median()
            df[name] = col.fillna(filler)
            na_dict[name] = filler
    return na_dict

def numericalize(df, col, name, max_n_cat):
    """ Changes the column col from a categorical type to it's integer codes.

    Parameters:
    -----------
    df: A pandas dataframe. df[name] will be filled with the integer codes from
        col.

    col: The column you wish to change into the categories.
    name: The column name you wish to insert into df. This column will hold the
        integer codes.

    max_n_cat: If col has more categories than max_n_cat it will not change the
        it to its integer codes. If max_n_cat is None, then col will always be
        converted.

    Examples:
    ---------
    >>> df = pd.DataFrame({'col1' : [1, 2, 3], 'col2' : ['a', 'b', 'a']})
    >>> df
       col1 col2
    0     1    a
    1     2    b
    2     3    a

    note the type of col2 is string

    >>> train_cats(df)
    >>> df

       col1 col2
    0     1    a
    1     2    b
    2     3    a

    now the type of col2 is category { a : 1, b : 2}

    >>> numericalize(df, df['col2'], 'col3', None)

       col1 col2 col3
    0     1    a    1
    1     2    b    2
    2     3    a    1
    """
    if not is_numeric_dtype(col) and ( max_n_cat is None or len(col.cat.categories)>max_n_cat):
        df[name] = col.cat.codes+1

def scale_vars(df, mapper):
    warnings.filterwarnings('ignore', category=sklearn.exceptions.DataConversionWarning)
    if mapper is None:
        map_f = [([n],StandardScaler()) for n in df.columns if is_numeric_dtype(df[n])]
        mapper = DataFrameMapper(map_f).fit(df)
    df[mapper.transformed_names_] = mapper.transform(df)
    return mapper

def proc_df(df, y_fld=None, skip_flds=None, ignore_flds=None, do_scale=False, na_dict=None,
            preproc_fn=None, max_n_cat=None, subset=None, mapper=None):
    """ proc_df takes a data frame df and splits off the response variable, and
    changes the df into an entirely numeric dataframe. For each column of df 
    which is not in skip_flds nor in ignore_flds, na values are replaced by the
    median value of the column.

    Parameters:
    -----------
    df: The data frame you wish to process.

    y_fld: The name of the response variable

    skip_flds: A list of fields that dropped from df.

    ignore_flds: A list of fields that are ignored during processing.

    do_scale: Standardizes each column in df. Takes Boolean Values(True,False)

    na_dict: a dictionary of na columns to add. Na columns are also added if there
        are any missing values.

    preproc_fn: A function that gets applied to df.

    max_n_cat: The maximum number of categories to break into dummy values, instead
        of integer codes.

    subset: Takes a random subset of size subset from df.

    mapper: If do_scale is set as True, the mapper variable
        calculates the values used for scaling of variables during training time (mean and standard deviation).

    Returns:
    --------
    [x, y, nas, mapper(optional)]:

        x: x is the transformed version of df. x will not have the response variable
            and is entirely numeric.

        y: y is the response variable

        nas: returns a dictionary of which nas it created, and the associated median.

        mapper: A DataFrameMapper which stores the mean and standard deviation of the corresponding continuous
        variables which is then used for scaling of during test-time.

    Examples:
    ---------
    >>> df = pd.DataFrame({'col1' : [1, 2, 3], 'col2' : ['a', 'b', 'a']})
    >>> df
       col1 col2
    0     1    a
    1     2    b
    2     3    a

    note the type of col2 is string

    >>> train_cats(df)
    >>> df

       col1 col2
    0     1    a
    1     2    b
    2     3    a

    now the type of col2 is category { a : 1, b : 2}

    >>> x, y, nas = proc_df(df, 'col1')
    >>> x

       col2
    0     1
    1     2
    2     1

    >>> data = DataFrame(pet=["cat", "dog", "dog", "fish", "cat", "dog", "cat", "fish"],
                 children=[4., 6, 3, 3, 2, 3, 5, 4],
                 salary=[90, 24, 44, 27, 32, 59, 36, 27])

    >>> mapper = DataFrameMapper([(:pet, LabelBinarizer()),
                          ([:children], StandardScaler())])

    >>>round(fit_transform!(mapper, copy(data)), 2)

    8x4 Array{Float64,2}:
    1.0  0.0  0.0   0.21
    0.0  1.0  0.0   1.88
    0.0  1.0  0.0  -0.63
    0.0  0.0  1.0  -0.63
    1.0  0.0  0.0  -1.46
    0.0  1.0  0.0  -0.63
    1.0  0.0  0.0   1.04
    0.0  0.0  1.0   0.21
    """
    if not ignore_flds: ignore_flds=[]
    if not skip_flds: skip_flds=[]
    if subset: df = get_sample(df,subset)
    else: df = df.copy()
    ignored_flds = df.loc[:, ignore_flds]
    df.drop(ignore_flds, axis=1, inplace=True)
    if preproc_fn: preproc_fn(df)
    if y_fld is None: y = None
    else:
        if not is_numeric_dtype(df[y_fld]): df[y_fld] = df[y_fld].cat.codes
        y = df[y_fld].values
        skip_flds += [y_fld]
    df.drop(skip_flds, axis=1, inplace=True)

    if na_dict is None: na_dict = {}
    else: na_dict = na_dict.copy()
    na_dict_initial = na_dict.copy()
    for n,c in df.items(): na_dict = fix_missing(df, c, n, na_dict)
    if len(na_dict_initial.keys()) > 0:
        df.drop([a + '_na' for a in list(set(na_dict.keys()) - set(na_dict_initial.keys()))], axis=1, inplace=True)
    if do_scale: mapper = scale_vars(df, mapper)
    for n,c in df.items(): numericalize(df, c, n, max_n_cat)
    df = pd.get_dummies(df, dummy_na=True)
    df = pd.concat([ignored_flds, df], axis=1)
    res = [df, y, na_dict]
    if do_scale: res = res + [mapper]
    return res

def rf_feat_importance(m, df):
    return pd.DataFrame({'cols':df.columns, 'imp':m.feature_importances_}
                       ).sort_values('imp', ascending=False)

def set_rf_samples(n):
    """ Changes Scikit learn's random forests to give each tree a random sample of
    n random rows.
    """
    forest._generate_sample_indices = (lambda rs, n_samples:
        forest.check_random_state(rs).randint(0, n_samples, n))

def reset_rf_samples():
    """ Undoes the changes produced by set_rf_samples.
    """
    forest._generate_sample_indices = (lambda rs, n_samples:
        forest.check_random_state(rs).randint(0, n_samples, n_samples))

def get_nn_mappers(df, cat_vars, contin_vars):
    # Replace nulls with 0 for continuous, "" for categorical.
    for v in contin_vars: df[v] = df[v].fillna(df[v].max()+100,)
    for v in cat_vars: df[v].fillna('#NA#', inplace=True)

    # list of tuples, containing variable and instance of a transformer for that variable
    # for categoricals, use LabelEncoder to map to integers. For continuous, standardize
    cat_maps = [(o, LabelEncoder()) for o in cat_vars]
    contin_maps = [([o], StandardScaler()) for o in contin_vars]
    return DataFrameMapper(cat_maps).fit(df), DataFrameMapper(contin_maps).fit(df)

# %% [markdown]
# # **Helper Method to reduce memory Usage**

# %%
# Memory saving function credit to https://www.kaggle.com/gemartin/load-data-reduce-memory-usage
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.
    """
    start_mem = df.memory_usage().sum() / 1024**2
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                #if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                #    df[col] = df[col].astype(np.float16)
                #el
                if c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        #else:
            #df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB --> {:.2f} MB (Decreased by {:.1f}%)'.format(
        start_mem, end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
PATH = "../input/"

# %%
# %%time 
df_raw_train = pd.read_csv(f'{PATH}train_V2.csv', low_memory=False)
df_raw_train = reduce_mem_usage(df_raw_train)
df_raw_test = pd.read_csv(f'{PATH}test_V2.csv', low_memory = False)
df_raw_test = reduce_mem_usage(df_raw_test)
# Out:
# Memory usage of dataframe is 983.90 MB --> 339.28 MB (Decreased by 65.5%)
# Memory usage of dataframe is 413.18 MB --> 140.19 MB (Decreased by 66.1%)
# CPU times: user 54.4 s, sys: 18.2 s, total: 1min 12s
# Wall time: 1min 12s

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

# %%
display_all(df_raw_train.describe(include='all').T)
# Out:
#                        count   unique             top     freq        mean  \
# Id                   4446966  4446966  912e0d9cd90fa2        1         NaN
# groupId              4446966  2026745  14d6b54cdec6bc       74         NaN
# matchId              4446966    47965  e90703b941c398      100         NaN
# assists          4.44697e+06      NaN             NaN      NaN    0.233815
# boosts           4.44697e+06      NaN             NaN      NaN     1.10691
# damageDealt      4.44697e+06      NaN             NaN      NaN     130.633
# DBNOs            4.44697e+06      NaN             NaN      NaN    0.657876
# headshotKills    4.44697e+06      NaN             NaN      NaN     0.22682
# heals            4.44697e+06      NaN             NaN      NaN     1.37015
# killPlace        4.44697e+06      NaN             NaN      NaN     47.5994
# killPoints       4.44697e+06      NaN             NaN      NaN     505.006
# kills            4.44697e+06      NaN             NaN      NaN    0.924783
# killStreaks      4.44697e+06      NaN             NaN      NaN    0.543955
# longestKill      4.44697e+06      NaN             NaN      NaN     22.9935
# matchDuration    4.44697e+06      NaN             NaN      NaN     1579.51
# matchType            4446966       16       squad-fpp  1756186         NaN
# maxPlace         4.44697e+06      NaN             NaN      NaN     44.5047
# numGroups        4.44697e+06      NaN             NaN      NaN     43.0076
# rankPoints       4.44697e+06      NaN             NaN      NaN      892.01
# revives          4.44697e+06      NaN             NaN      NaN    0.164659
# rideDistance     4.44697e+06      NaN             NaN      NaN     606.092
# roadKills        4.44697e+06      NaN             NaN      NaN  0.00349609
# swimDistance     4.44697e+06      NaN             NaN      NaN     4.50924
# teamKills        4.44697e+06      NaN             NaN      NaN   0.0238684
# vehicleDestroys  4.44697e+06      NaN             NaN      NaN  0.00791821
# walkDistance     4.44697e+06      NaN             NaN      NaN     1148.52
# weaponsAcquired  4.44697e+06      NaN             NaN      NaN     3.66049
# winPoints        4.44697e+06      NaN             NaN      NaN      606.46
# winPlacePerc     4.44696e+06      NaN             NaN      NaN    0.472814
#
#                        std  min    25%     50%       75%    max
# Id                     NaN  NaN    NaN     NaN       NaN    NaN
# groupId                NaN  NaN    NaN     NaN       NaN    NaN
# matchId                NaN  NaN    NaN     NaN       NaN    NaN
# assists           0.588573    0      0       0         0     22
# boosts             1.71579    0      0       0         2     33
# damageDealt        169.887    0      0   84.24       186   6616
# DBNOs              1.14574    0      0       0         1     53
# headshotKills     0.602155    0      0       0         0     64
# heals              2.67998    0      0       0         2     80
# killPlace          27.4629    1     24      47        71    101
# killPoints         627.505    0      0       0      1172   2170
# kills              1.55844    0      0       0         1     72
# killStreaks       0.710972    0      0       0         1     20
# longestKill        51.4761    0      0       0     21.32   1094
# matchDuration       258.74    9   1367    1438      1851   2237
# matchType              NaN  NaN    NaN     NaN       NaN    NaN
# maxPlace           23.8281    1     28      30        49    100
# numGroups          23.2895    1     27      30        47    100
# rankPoints         736.648   -1     -1    1443      1500   5910
# revives           0.472167    0      0       0         0     39
# rideDistance       1496.47    0      0       0  0.190975  40710
# roadKills         0.073373    0      0       0         0     18
# swimDistance       30.2378    0      0       0         0   3823
# teamKills         0.167394    0      0       0         0     12
# vehicleDestroys  0.0926116    0      0       0         0      5
# walkDistance       1180.55    0  155.1   685.6      1976  25780
# weaponsAcquired    2.45654    0      2       3         5    236
# winPoints            739.7    0      0       0      1495   2013
# winPlacePerc      0.306804    0    0.2  0.4583    0.7407      1

# %% [markdown]
# # **Handling null values**

# %%
null_cnt = df_raw_train.isnull().sum().sort_values()
print('null count:', null_cnt[null_cnt > 0])
# Out:
# null count: winPlacePerc    1
# dtype: int64

# %%
df_raw_train.dropna(inplace=True)

# %%
df_raw_train = df_raw_train.sort_values(by = ['matchId'])

# %% [markdown]
# **There are lot of variations of MatchType but basically we can categorise them all to solo, duo or squad**

# %%
mapper = lambda x: 'solo' if ('solo' in x) else 'duo' if ('duo' in x) or ('crash' in x) else 'squad'

# %%
df_raw_train['matchType'] = df_raw_train['matchType'].apply(mapper)

# %%
train_cats(df_raw_train)

# %%
df, y, nas = proc_df(df_raw_train, 'winPlacePerc')

# %%
def split_vals(a,n): return a[:n].copy(), a[n:].copy()

# %%
n_valid = 1000000
n_trn = len(df)-n_valid
raw_train, raw_valid = split_vals(df, n_trn)
X_train, X_valid = split_vals(df, n_trn)
y_train, y_valid = split_vals(y, n_trn)

X_train.shape, y_train.shape, X_valid.shape
# Out:
# ((3446965, 28), (3446965,), (1000000, 28))

# %%
def rmse(x,y): return np.sqrt(((x-y)**2).mean())

def print_score(m):
    res = [rmse(m.predict(X_train[features]), y_train), rmse(m.predict(X_valid[features]), y_valid),
                m.score(X_train[features], y_train), m.score(X_valid[features], y_valid)]
    if hasattr(m, 'oob_score_'): res.append(m.oob_score_)
    print(res)

# %%
# Training on subset of the data initially to do analysis fast.
X_train = X_train[:1000000]
y_train = y_train[:1000000]

# %%
X_train.head()
# Out:
#               Id  groupId    ...      weaponsAcquired  winPoints
# 3599150  4384174   463842    ...                    1       1557
# 1185914  2886511   810649    ...                    8       1559
# 7931     2798432   982089    ...                    3       1502
# 918045    728674   603063    ...                    2       1433
# 518453   3443301  1467243    ...                    5       1521
#
# [5 rows x 28 columns]

# %%
# Training on simple model without removing matchId, Id and groupId. Just to visualise the decision tree
m = RandomForestRegressor(n_estimators=1, max_depth=3, bootstrap=False, n_jobs=-1)
m.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=False, criterion='mse', max_depth=3,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
rmse(m.predict(X_train), y_train)
# Out:
# 0.13774874296384126

# %%
draw_tree(m.estimators_[0], X_train, precision=3)

# %%
def fillInf(df, val):
    numcols = df.select_dtypes(include='number').columns
    cols = numcols[numcols != 'winPlacePerc']
    df[df == np.Inf] = np.NaN
    df[df == np.NINF] = np.NaN
    for c in cols: df[c].fillna(val, inplace=True)

# %%
features = list(X_train.columns)
features
# Out:
# ['Id',
#  'groupId',
#  'matchId',
#  'assists',
#  'boosts',
#  'damageDealt',
#  'DBNOs',
#  'headshotKills',
#  'heals',
#  'killPlace',
#  'killPoints',
#  'kills',
#  'killStreaks',
#  'longestKill',
#  'matchDuration',
#  'matchType',
#  'maxPlace',
#  'numGroups',
#  'rankPoints',
#  'revives',
#  'rideDistance',
#  'roadKills',
#  'swimDistance',
#  'teamKills',
#  'vehicleDestroys',
#  'walkDistance',
#  'weaponsAcquired',
#  'winPoints']

# %%
features.remove('Id')
features.remove('groupId')
features.remove('matchId')

# %%
# Fitting using a basic Random Forest
m = RandomForestRegressor(n_jobs=-1)
m.fit(X_train[features], y_train)
print_score(m)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [0.036850692012286544, 0.08810425458251832, 0.9856363348020404, 0.9178482555274257]

# %% [markdown]
# # **Analysing the feature importance with basic features**

# %%
fi = rf_feat_importance(m, X_train[features]); fi
# Out:
#                cols       imp
# 22     walkDistance  0.698551
# 6         killPlace  0.181395
# 14        numGroups  0.021988
# 11    matchDuration  0.018770
# 13         maxPlace  0.009289
# 8             kills  0.007671
# 17     rideDistance  0.007478
# 2       damageDealt  0.007266
# 10      longestKill  0.006050
# 15       rankPoints  0.005836
# 1            boosts  0.005554
# 9       killStreaks  0.004861
# 23  weaponsAcquired  0.004773
# 3             DBNOs  0.004048
# 24        winPoints  0.003416
# 5             heals  0.003232
# 7        killPoints  0.003125
# 12        matchType  0.001752
# 0           assists  0.001690
# 16          revives  0.001012
# 19     swimDistance  0.000892
# 4     headshotKills  0.000886
# 20        teamKills  0.000305
# 21  vehicleDestroys  0.000098
# 18        roadKills  0.000063

# %%
def plot_fi(fi): return fi.plot('cols', 'imp', 'barh', figsize=(12,7), legend=False)

# %%
plot_fi(fi[:30])

# %% [markdown]
# # **Adding new features.**
# The features which we can be broadly categorised into three categories. Individual, Group wise, Match wise. In **solo** matchtype no of groups will  be equal to no of players and in **duo** players will participate in groups of two and in **squad** players will participate in groups of 4. Using stats which summarise the group and match may be helpful

# %%
X_train['headshot_percentage'] = X_train['headshotKills']/X_train['kills']
X_valid['headshot_percentage'] = X_valid['headshotKills']/X_valid['kills']

X_train['totalDistance'] = X_train['rideDistance'] + X_train['walkDistance'] + X_train['swimDistance']
X_valid['totalDistance'] = X_valid['rideDistance'] + X_valid['walkDistance'] + X_valid['swimDistance']

X_train['health_items'] = X_train['heals'] + X_train['boosts']
X_train['killPlaceOverMaxPlace'] = X_train['killPlace'] / X_train['maxPlace']
X_train['killsOverWalkDistance'] = X_train['kills'] / X_train['walkDistance']

X_valid['health_items'] = X_valid['heals'] + X_train['boosts']
X_valid['killPlaceOverMaxPlace'] = X_valid['killPlace'] / X_train['maxPlace']
X_valid['killsOverWalkDistance'] = X_valid['kills'] / X_train['walkDistance']

X_train['killStreakRate'] = X_train['killStreaks']/X_train['kills']
X_valid['killStreakRate'] = X_valid['killStreaks']/X_valid['kills']

X_train['killMinute'] = X_train['kills'] / X_train['matchDuration']
X_valid['killMinute'] = X_valid['kills'] / X_valid['matchDuration']

X_train['damageDealtMinute'] = X_train['damageDealt'] / X_train['matchDuration']
X_valid['damageDealtMinute'] = X_valid['damageDealt'] / X_valid['matchDuration']

X_train['participateKills'] = X_train['kills'] + X_train['assists'] + X_train['DBNOs']
X_valid['participateKills'] = X_valid['kills'] + X_valid['assists'] + X_valid['DBNOs']

X_train['vehicleDestroysMinute'] = X_train['vehicleDestroys'] / X_train['matchDuration']
X_valid['vehicleDestroysMinute'] = X_valid['vehicleDestroys'] / X_valid['matchDuration']

X_train['killsMiter'] = X_train['roadKills'] / X_train['rideDistance']
X_valid['killsMiter'] = X_valid['roadKills'] / X_valid['rideDistance']

X_train['playersJoined'] = X_train.groupby('matchId')['matchId'].transform('count')

X_train['killsNorm'] = X_train['kills']*((100-X_train['playersJoined'])/100)
X_train['damageDealtNorm'] = X_train['damageDealt']*((100-X_train['playersJoined'])/100)

X_train['boostsPerWalkDistance'] = X_train['boosts']/(X_train['walkDistance']) 

X_train['healsPerWalkDistance'] = X_train['heals']/(X_train['walkDistance'])

X_train['healsAndBoosts'] = X_train['heals']+X_train['boosts']

X_train['healsAndBoostsPerWalkDistance'] = X_train['healsAndBoosts']/(X_train['walkDistance'])

X_valid['playersJoined'] = X_valid.groupby('matchId')['matchId'].transform('count')

X_valid['killsNorm'] = X_valid['kills']*((100-X_valid['playersJoined'])/100)
X_valid['damageDealtNorm'] = X_valid['damageDealt']*((100-X_valid['playersJoined'])/100)

X_valid['boostsPerWalkDistance'] = X_valid['boosts']/(X_train['walkDistance']) 

X_valid['healsPerWalkDistance'] = X_valid['heals']/(X_train['walkDistance'])

X_valid['healsAndBoosts'] = X_valid['heals'] + X_valid['boosts']

X_valid['healsAndBoostsPerWalkDistance'] = X_valid['healsAndBoosts']/(X_valid['walkDistance'])

# %%
train_group_agg = X_train.groupby(['matchId', 'groupId', 'matchType'])
val_group_agg =  X_valid.groupby(['matchId', 'groupId', 'matchType'])

train_match_agg = X_train.groupby(['matchId'])
val_match_agg = X_valid.groupby(['matchId'])

# %%
X_train.columns
# Out:
# Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
#        'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
#        'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
#        'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
#        'weaponsAcquired', 'winPoints', 'headshot_percentage', 'totalDistance',
#        'health_items', 'killPlaceOverMaxPlace', 'killsOverWalkDistance',
#        'killStreakRate', 'killMinute', 'damageDealtMinute', 'participateKills',
#        'vehicleDestroysMinute', 'killsMiter', 'playersJoined', 'killsNorm',
#        'damageDealtNorm', 'boostsPerWalkDistance', 'healsPerWalkDistance',
#        'healsAndBoosts', 'healsAndBoostsPerWalkDistance'],
#       dtype='object')

# %%
features = list(X_train.columns)
features.remove('matchId')
features.remove('groupId')
features.remove('Id')

# %%
agg_col = features
agg_col.remove('matchType')
agg_col.remove('numGroups')
agg_col.remove('maxPlace')
agg_col
# Out:
# ['assists',
#  'boosts',
#  'damageDealt',
#  'DBNOs',
#  'headshotKills',
#  'heals',
#  'killPlace',
#  'killPoints',
#  'kills',
#  'killStreaks',
#  'longestKill',
#  'matchDuration',
#  'rankPoints',
#  'revives',
#  'rideDistance',
#  'roadKills',
#  'swimDistance',
#  'teamKills',
#  'vehicleDestroys',
#  'walkDistance',
#  'weaponsAcquired',
#  'winPoints',
#  'headshot_percentage',
#  'totalDistance',
#  'health_items',
#  'killPlaceOverMaxPlace',
#  'killsOverWalkDistance',
#  'killStreakRate',
#  'killMinute',
#  'damageDealtMinute',
#  'participateKills',
#  'vehicleDestroysMinute',
#  'killsMiter',
#  'playersJoined',
#  'killsNorm',
#  'damageDealtNorm',
#  'boostsPerWalkDistance',
#  'healsPerWalkDistance',
#  'healsAndBoosts',
#  'healsAndBoostsPerWalkDistance']

# %%
features
# Out:
# ['assists',
#  'boosts',
#  'damageDealt',
#  'DBNOs',
#  'headshotKills',
#  'heals',
#  'killPlace',
#  'killPoints',
#  'kills',
#  'killStreaks',
#  'longestKill',
#  'matchDuration',
#  'rankPoints',
#  'revives',
#  'rideDistance',
#  'roadKills',
#  'swimDistance',
#  'teamKills',
#  'vehicleDestroys',
#  'walkDistance',
#  'weaponsAcquired',
#  'winPoints',
#  'headshot_percentage',
#  'totalDistance',
#  'health_items',
#  'killPlaceOverMaxPlace',
#  'killsOverWalkDistance',
#  'killStreakRate',
#  'killMinute',
#  'damageDealtMinute',
#  'participateKills',
#  'vehicleDestroysMinute',
#  'killsMiter',
#  'playersJoined',
#  'killsNorm',
#  'damageDealtNorm',
#  'boostsPerWalkDistance',
#  'healsPerWalkDistance',
#  'healsAndBoosts',
#  'healsAndBoostsPerWalkDistance']

# %%
fillInf(X_train, 0)
fillInf(X_valid, 0)

# %%
for col in agg_col :
    X_train['percentage_match_' + col] = train_match_agg[col].rank(pct=True).values
    X_valid['percentage_match_' + col] = val_match_agg[col].rank(pct=True).values

# %%
X_train = X_train.merge(train_match_agg[agg_col].max().rename(columns=lambda s: 'match_max_' + s), on = 'matchId', how = 'left')
X_valid = X_valid.merge(val_match_agg[agg_col].max().rename(columns=lambda s: 'match_max_' + s), on = 'matchId', how = 'left')

# %%
X_train = X_train.merge(train_match_agg[agg_col].min().rename(columns=lambda s: 'match_min_' + s), on = 'matchId', how = 'left')
X_valid = X_valid.merge(val_match_agg[agg_col].min().rename(columns=lambda s: 'match_min_' + s), on = 'matchId', how = 'left')

# %%
X_train = X_train.merge(train_match_agg[agg_col].mean().rename(columns=lambda s: 'match_mean_' + s), on = 'matchId', how = 'left')
X_valid = X_valid.merge(val_match_agg[agg_col].mean().rename(columns=lambda s: 'match_mean_' + s), on = 'matchId', how = 'left')

# %%
display_all(X_train.head().T)
# Out:
#                                                            0             1  \
# Id                                              4.384174e+06  2.886511e+06
# groupId                                         4.638420e+05  8.106490e+05
# matchId                                         1.000000e+00  1.000000e+00
# assists                                         0.000000e+00  1.000000e+00
# boosts                                          0.000000e+00  1.000000e+00
# damageDealt                                     0.000000e+00  2.561000e+02
# DBNOs                                           0.000000e+00  3.000000e+00
# headshotKills                                   0.000000e+00  0.000000e+00
# heals                                           0.000000e+00  0.000000e+00
# killPlace                                       9.500000e+01  3.800000e+01
# killPoints                                      1.458000e+03  1.372000e+03
# kills                                           0.000000e+00  0.000000e+00
# killStreaks                                     0.000000e+00  0.000000e+00
# longestKill                                     0.000000e+00  0.000000e+00
# matchDuration                                   1.346000e+03  1.346000e+03
# matchType                                       3.000000e+00  3.000000e+00
# maxPlace                                        2.800000e+01  2.800000e+01
# numGroups                                       2.800000e+01  2.800000e+01
# rankPoints                                      0.000000e+00  0.000000e+00
# revives                                         0.000000e+00  1.000000e+00
# rideDistance                                    0.000000e+00  2.202000e+03
# roadKills                                       0.000000e+00  0.000000e+00
# swimDistance                                    0.000000e+00  0.000000e+00
# teamKills                                       0.000000e+00  0.000000e+00
# vehicleDestroys                                 0.000000e+00  0.000000e+00
# walkDistance                                    9.636000e+00  2.400000e+03
# weaponsAcquired                                 1.000000e+00  8.000000e+00
# winPoints                                       1.557000e+03  1.559000e+03
# headshot_percentage                             0.000000e+00  0.000000e+00
# totalDistance                                   9.636000e+00  4.602000e+03
# health_items                                    0.000000e+00  1.000000e+00
# killPlaceOverMaxPlace                           3.392857e+00  1.357143e+00
# killsOverWalkDistance                           0.000000e+00  0.000000e+00
# killStreakRate                                  0.000000e+00  0.000000e+00
# killMinute                                      0.000000e+00  0.000000e+00
# damageDealtMinute                               0.000000e+00  1.902675e-01
# participateKills                                0.000000e+00  4.000000e+00
# vehicleDestroysMinute                           0.000000e+00  0.000000e+00
# killsMiter                                      0.000000e+00  0.000000e+00
# playersJoined                                   9.500000e+01  9.500000e+01
# killsNorm                                       0.000000e+00  0.000000e+00
# damageDealtNorm                                 0.000000e+00  1.280500e+01
# boostsPerWalkDistance                           0.000000e+00  4.166667e-04
# healsPerWalkDistance                            0.000000e+00  0.000000e+00
# healsAndBoosts                                  0.000000e+00  1.000000e+00
# healsAndBoostsPerWalkDistance                   0.000000e+00  4.166667e-04
# percentage_match_assists                        3.842105e-01  8.526316e-01
# percentage_match_boosts                         2.684211e-01  6.052632e-01
# percentage_match_damageDealt                    1.421053e-01  8.105263e-01
# percentage_match_DBNOs                          3.000000e-01  9.157895e-01
# percentage_match_headshotKills                  4.263158e-01  4.263158e-01
# percentage_match_heals                          3.052632e-01  3.052632e-01
# percentage_match_killPlace                      1.000000e+00  4.000000e-01
# percentage_match_killPoints                     7.789474e-01  6.210526e-01
# percentage_match_kills                          3.210526e-01  3.210526e-01
# percentage_match_killStreaks                    3.210526e-01  3.210526e-01
# percentage_match_longestKill                    3.210526e-01  3.210526e-01
# percentage_match_matchDuration                  5.052632e-01  5.052632e-01
# percentage_match_rankPoints                     5.052632e-01  5.052632e-01
# percentage_match_revives                        4.315789e-01  9.263158e-01
# percentage_match_rideDistance                   4.105263e-01  1.000000e+00
# percentage_match_roadKills                      5.052632e-01  5.052632e-01
# percentage_match_swimDistance                   4.421053e-01  4.421053e-01
# percentage_match_teamKills                      5.000000e-01  5.000000e-01
# percentage_match_vehicleDestroys                4.947368e-01  4.947368e-01
# percentage_match_walkDistance                   4.210526e-02  7.578947e-01
# percentage_match_weaponsAcquired                1.684211e-01  9.842105e-01
# percentage_match_winPoints                      9.210526e-01  9.368421e-01
# percentage_match_headshot_percentage            4.263158e-01  4.263158e-01
# percentage_match_totalDistance                  4.210526e-02  1.000000e+00
# percentage_match_health_items                   2.368421e-01  5.210526e-01
# percentage_match_killPlaceOverMaxPlace          1.000000e+00  4.000000e-01
# percentage_match_killsOverWalkDistance          3.210526e-01  3.210526e-01
# percentage_match_killStreakRate                 3.210526e-01  3.210526e-01
# percentage_match_killMinute                     3.210526e-01  3.210526e-01
# percentage_match_damageDealtMinute              1.421053e-01  8.105263e-01
# percentage_match_participateKills               2.473684e-01  8.105263e-01
# percentage_match_vehicleDestroysMinute          4.947368e-01  4.947368e-01
# percentage_match_killsMiter                     5.052632e-01  5.052632e-01
# percentage_match_playersJoined                  5.052632e-01  5.052632e-01
# percentage_match_killsNorm                      3.210526e-01  3.210526e-01
# percentage_match_damageDealtNorm                1.421053e-01  8.105263e-01
# percentage_match_boostsPerWalkDistance          2.684211e-01  5.684211e-01
# percentage_match_healsPerWalkDistance           3.052632e-01  3.052632e-01
# percentage_match_healsAndBoosts                 2.368421e-01  5.210526e-01
# percentage_match_healsAndBoostsPerWalkDistance  2.368421e-01  4.947368e-01
# match_max_assists                               4.000000e+00  4.000000e+00
# match_max_boosts                                8.000000e+00  8.000000e+00
# match_max_damageDealt                           9.837000e+02  9.837000e+02
# match_max_DBNOs                                 4.000000e+00  4.000000e+00
# match_max_headshotKills                         2.000000e+00  2.000000e+00
# match_max_heals                                 9.000000e+00  9.000000e+00
# match_max_killPlace                             9.500000e+01  9.500000e+01
# match_max_killPoints                            1.862000e+03  1.862000e+03
# match_max_kills                                 7.000000e+00  7.000000e+00
# match_max_killStreaks                           4.000000e+00  4.000000e+00
# match_max_longestKill                           1.925000e+02  1.925000e+02
# match_max_matchDuration                         1.346000e+03  1.346000e+03
# match_max_rankPoints                            0.000000e+00  0.000000e+00
# match_max_revives                               2.000000e+00  2.000000e+00
# match_max_rideDistance                          2.202000e+03  2.202000e+03
# match_max_roadKills                             0.000000e+00  0.000000e+00
# match_max_swimDistance                          1.416000e+02  1.416000e+02
# match_max_teamKills                             1.000000e+00  1.000000e+00
# match_max_vehicleDestroys                       1.000000e+00  1.000000e+00
# match_max_walkDistance                          3.438000e+03  3.438000e+03
# match_max_weaponsAcquired                       1.200000e+01  1.200000e+01
# match_max_winPoints                             1.679000e+03  1.679000e+03
# match_max_headshot_percentage                   1.000000e+00  1.000000e+00
# match_max_totalDistance                         4.602000e+03  4.602000e+03
# match_max_health_items                          1.600000e+01  1.600000e+01
# match_max_killPlaceOverMaxPlace                 3.392857e+00  3.392857e+00
# match_max_killsOverWalkDistance                 2.703799e-02  2.703799e-02
# match_max_killStreakRate                        1.000000e+00  1.000000e+00
# match_max_killMinute                            5.200594e-03  5.200594e-03
# match_max_damageDealtMinute                     7.308321e-01  7.308321e-01
# match_max_participateKills                      1.300000e+01  1.300000e+01
# match_max_vehicleDestroysMinute                 7.429421e-04  7.429421e-04
# match_max_killsMiter                            0.000000e+00  0.000000e+00
# match_max_playersJoined                         9.500000e+01  9.500000e+01
# match_max_killsNorm                             3.500000e-01  3.500000e-01
# match_max_damageDealtNorm                       4.918500e+01  4.918500e+01
# match_max_boostsPerWalkDistance                 2.759890e-02  2.759890e-02
# match_max_healsPerWalkDistance                  4.599816e-02  4.599816e-02
# match_max_healsAndBoosts                        1.600000e+01  1.600000e+01
# match_max_healsAndBoostsPerWalkDistance         7.359706e-02  7.359706e-02
# match_min_assists                               0.000000e+00  0.000000e+00
# match_min_boosts                                0.000000e+00  0.000000e+00
# match_min_damageDealt                           0.000000e+00  0.000000e+00
# match_min_DBNOs                                 0.000000e+00  0.000000e+00
# match_min_headshotKills                         0.000000e+00  0.000000e+00
# match_min_heals                                 0.000000e+00  0.000000e+00
# match_min_killPlace                             1.000000e+00  1.000000e+00
# match_min_killPoints                            1.000000e+03  1.000000e+03
# match_min_kills                                 0.000000e+00  0.000000e+00
# match_min_killStreaks                           0.000000e+00  0.000000e+00
# match_min_longestKill                           0.000000e+00  0.000000e+00
# match_min_matchDuration                         1.346000e+03  1.346000e+03
# match_min_rankPoints                            0.000000e+00  0.000000e+00
# match_min_revives                               0.000000e+00  0.000000e+00
# match_min_rideDistance                          0.000000e+00  0.000000e+00
# match_min_roadKills                             0.000000e+00  0.000000e+00
# match_min_swimDistance                          0.000000e+00  0.000000e+00
# match_min_teamKills                             0.000000e+00  0.000000e+00
# match_min_vehicleDestroys                       0.000000e+00  0.000000e+00
# match_min_walkDistance                          0.000000e+00  0.000000e+00
# match_min_weaponsAcquired                       0.000000e+00  0.000000e+00
# match_min_winPoints                             1.399000e+03  1.399000e+03
# match_min_headshot_percentage                   0.000000e+00  0.000000e+00
# match_min_totalDistance                         0.000000e+00  0.000000e+00
# match_min_health_items                          0.000000e+00  0.000000e+00
# match_min_killPlaceOverMaxPlace                 3.571429e-02  3.571429e-02
# match_min_killsOverWalkDistance                 0.000000e+00  0.000000e+00
# match_min_killStreakRate                        0.000000e+00  0.000000e+00
# match_min_killMinute                            0.000000e+00  0.000000e+00
# match_min_damageDealtMinute                     0.000000e+00  0.000000e+00
# match_min_participateKills                      0.000000e+00  0.000000e+00
# match_min_vehicleDestroysMinute                 0.000000e+00  0.000000e+00
# match_min_killsMiter                            0.000000e+00  0.000000e+00
# match_min_playersJoined                         9.500000e+01  9.500000e+01
# match_min_killsNorm                             0.000000e+00  0.000000e+00
# match_min_damageDealtNorm                       0.000000e+00  0.000000e+00
# match_min_boostsPerWalkDistance                 0.000000e+00  0.000000e+00
# match_min_healsPerWalkDistance                  0.000000e+00  0.000000e+00
# match_min_healsAndBoosts                        0.000000e+00  0.000000e+00
# match_min_healsAndBoostsPerWalkDistance         0.000000e+00  0.000000e+00
# match_mean_assists                              3.578947e-01  3.578947e-01
# match_mean_boosts                               1.242105e+00  1.242105e+00
# match_mean_damageDealt                          1.425239e+02  1.425239e+02
# match_mean_DBNOs                                8.421053e-01  8.421053e-01
# match_mean_headshotKills                        1.789474e-01  1.789474e-01
# match_mean_heals                                1.115789e+00  1.115789e+00
# match_mean_killPlace                            4.800000e+01  4.800000e+01
# match_mean_killPoints                           1.321547e+03  1.321547e+03
# match_mean_kills                                9.473684e-01  9.473684e-01
# match_mean_killStreaks                          5.473684e-01  5.473684e-01
# match_mean_longestKill                          1.978105e+01  1.978105e+01
# match_mean_matchDuration                        1.346000e+03  1.346000e+03
# match_mean_rankPoints                           0.000000e+00  0.000000e+00
# match_mean_revives                              1.578947e-01  1.578947e-01
# match_mean_rideDistance                         9.263123e+01  9.263123e+01
# match_mean_roadKills                            0.000000e+00  0.000000e+00
# match_mean_swimDistance                         3.761548e+00  3.761548e+00
# match_mean_teamKills                            1.052632e-02  1.052632e-02
# match_mean_vehicleDestroys                      2.105263e-02  2.105263e-02
# match_mean_walkDistance                         1.253503e+03  1.253503e+03
# match_mean_weaponsAcquired                      3.073684e+00  3.073684e+00
# match_mean_winPoints                            1.490632e+03  1.490632e+03
# match_mean_headshot_percentage                  7.315789e-02  7.315789e-02
# match_mean_totalDistance                        1.349896e+03  1.349896e+03
# match_mean_health_items                         2.357895e+00  2.357895e+00
# match_mean_killPlaceOverMaxPlace                1.714286e+00  1.714286e+00
# match_mean_killsOverWalkDistance                1.412633e-03  1.412633e-03
# match_mean_killStreakRate                       2.690727e-01  2.690727e-01
# match_mean_killMinute                           7.038398e-04  7.038398e-04
# match_mean_damageDealtMinute                    1.058870e-01  1.058870e-01
# match_mean_participateKills                     2.147368e+00  2.147368e+00
# match_mean_vehicleDestroysMinute                1.564089e-05  1.564089e-05
# match_mean_killsMiter                           0.000000e+00  0.000000e+00
# match_mean_playersJoined                        9.500000e+01  9.500000e+01
# match_mean_killsNorm                            4.736842e-02  4.736842e-02
# match_mean_damageDealtNorm                      7.126195e+00  7.126195e+00
# match_mean_boostsPerWalkDistance                1.100960e-03  1.100960e-03
# match_mean_healsPerWalkDistance                 1.299162e-03  1.299162e-03
# match_mean_healsAndBoosts                       2.357895e+00  2.357895e+00
# match_mean_healsAndBoostsPerWalkDistance        2.400122e-03  2.400122e-03
#
#                                                            2              3  \
# Id                                              2.798432e+06  728674.000000
# groupId                                         9.820890e+05  603063.000000
# matchId                                         1.000000e+00       1.000000
# assists                                         0.000000e+00       0.000000
# boosts                                          1.000000e+00       0.000000
# damageDealt                                     0.000000e+00       0.000000
# DBNOs                                           0.000000e+00       0.000000
# headshotKills                                   0.000000e+00       0.000000
# heals                                           1.000000e+00       0.000000
# killPlace                                       4.100000e+01      60.000000
# killPoints                                      1.693000e+03    1189.000000
# kills                                           0.000000e+00       0.000000
# killStreaks                                     0.000000e+00       0.000000
# longestKill                                     0.000000e+00       0.000000
# matchDuration                                   1.346000e+03    1346.000000
# matchType                                       3.000000e+00       3.000000
# maxPlace                                        2.800000e+01      28.000000
# numGroups                                       2.800000e+01      28.000000
# rankPoints                                      0.000000e+00       0.000000
# revives                                         0.000000e+00       0.000000
# rideDistance                                    0.000000e+00       0.000000
# roadKills                                       0.000000e+00       0.000000
# swimDistance                                    0.000000e+00       0.000000
# teamKills                                       0.000000e+00       0.000000
# vehicleDestroys                                 0.000000e+00       0.000000
# walkDistance                                    2.723000e+03     347.700012
# weaponsAcquired                                 3.000000e+00       2.000000
# winPoints                                       1.502000e+03    1433.000000
# headshot_percentage                             0.000000e+00       0.000000
# totalDistance                                   2.723000e+03     347.700012
# health_items                                    2.000000e+00       0.000000
# killPlaceOverMaxPlace                           1.464286e+00       2.142857
# killsOverWalkDistance                           0.000000e+00       0.000000
# killStreakRate                                  0.000000e+00       0.000000
# killMinute                                      0.000000e+00       0.000000
# damageDealtMinute                               0.000000e+00       0.000000
# participateKills                                0.000000e+00       0.000000
# vehicleDestroysMinute                           0.000000e+00       0.000000
# killsMiter                                      0.000000e+00       0.000000
# playersJoined                                   9.500000e+01      95.000000
# killsNorm                                       0.000000e+00       0.000000
# damageDealtNorm                                 0.000000e+00       0.000000
# boostsPerWalkDistance                           3.672420e-04       0.000000
# healsPerWalkDistance                            3.672420e-04       0.000000
# healsAndBoosts                                  2.000000e+00       0.000000
# healsAndBoostsPerWalkDistance                   7.344840e-04       0.000000
# percentage_match_assists                        3.842105e-01       0.384211
# percentage_match_boosts                         6.052632e-01       0.268421
# percentage_match_damageDealt                    1.421053e-01       0.142105
# percentage_match_DBNOs                          3.000000e-01       0.300000
# percentage_match_headshotKills                  4.263158e-01       0.426316
# percentage_match_heals                          6.473684e-01       0.305263
# percentage_match_killPlace                      4.315789e-01       0.631579
# percentage_match_killPoints                     9.684211e-01       0.242105
# percentage_match_kills                          3.210526e-01       0.321053
# percentage_match_killStreaks                    3.210526e-01       0.321053
# percentage_match_longestKill                    3.210526e-01       0.321053
# percentage_match_matchDuration                  5.052632e-01       0.505263
# percentage_match_rankPoints                     5.052632e-01       0.505263
# percentage_match_revives                        4.315789e-01       0.431579
# percentage_match_rideDistance                   4.105263e-01       0.410526
# percentage_match_roadKills                      5.052632e-01       0.505263
# percentage_match_swimDistance                   4.421053e-01       0.442105
# percentage_match_teamKills                      5.000000e-01       0.500000
# percentage_match_vehicleDestroys                4.947368e-01       0.494737
# percentage_match_walkDistance                   8.421053e-01       0.463158
# percentage_match_weaponsAcquired                5.263158e-01       0.368421
# percentage_match_winPoints                      6.684211e-01       0.121053
# percentage_match_headshot_percentage            4.263158e-01       0.426316
# percentage_match_totalDistance                  8.105263e-01       0.452632
# percentage_match_health_items                   6.000000e-01       0.236842
# percentage_match_killPlaceOverMaxPlace          4.315789e-01       0.631579
# percentage_match_killsOverWalkDistance          3.210526e-01       0.321053
# percentage_match_killStreakRate                 3.210526e-01       0.321053
# percentage_match_killMinute                     3.210526e-01       0.321053
# percentage_match_damageDealtMinute              1.421053e-01       0.142105
# percentage_match_participateKills               2.473684e-01       0.247368
# percentage_match_vehicleDestroysMinute          4.947368e-01       0.494737
# percentage_match_killsMiter                     5.052632e-01       0.505263
# percentage_match_playersJoined                  5.052632e-01       0.505263
# percentage_match_killsNorm                      3.210526e-01       0.321053
# percentage_match_damageDealtNorm                1.421053e-01       0.142105
# percentage_match_boostsPerWalkDistance          5.473684e-01       0.268421
# percentage_match_healsPerWalkDistance           6.210526e-01       0.305263
# percentage_match_healsAndBoosts                 6.000000e-01       0.236842
# percentage_match_healsAndBoostsPerWalkDistance  5.473684e-01       0.236842
# match_max_assists                               4.000000e+00       4.000000
# match_max_boosts                                8.000000e+00       8.000000
# match_max_damageDealt                           9.837000e+02     983.700012
# match_max_DBNOs                                 4.000000e+00       4.000000
# match_max_headshotKills                         2.000000e+00       2.000000
# match_max_heals                                 9.000000e+00       9.000000
# match_max_killPlace                             9.500000e+01      95.000000
# match_max_killPoints                            1.862000e+03    1862.000000
# match_max_kills                                 7.000000e+00       7.000000
# match_max_killStreaks                           4.000000e+00       4.000000
# match_max_longestKill                           1.925000e+02     192.500000
# match_max_matchDuration                         1.346000e+03    1346.000000
# match_max_rankPoints                            0.000000e+00       0.000000
# match_max_revives                               2.000000e+00       2.000000
# match_max_rideDistance                          2.202000e+03    2202.000000
# match_max_roadKills                             0.000000e+00       0.000000
# match_max_swimDistance                          1.416000e+02     141.600006
# match_max_teamKills                             1.000000e+00       1.000000
# match_max_vehicleDestroys                       1.000000e+00       1.000000
# match_max_walkDistance                          3.438000e+03    3438.000000
# match_max_weaponsAcquired                       1.200000e+01      12.000000
# match_max_winPoints                             1.679000e+03    1679.000000
# match_max_headshot_percentage                   1.000000e+00       1.000000
# match_max_totalDistance                         4.602000e+03    4602.000000
# match_max_health_items                          1.600000e+01      16.000000
# match_max_killPlaceOverMaxPlace                 3.392857e+00       3.392857
# match_max_killsOverWalkDistance                 2.703799e-02       0.027038
# match_max_killStreakRate                        1.000000e+00       1.000000
# match_max_killMinute                            5.200594e-03       0.005201
# match_max_damageDealtMinute                     7.308321e-01       0.730832
# match_max_participateKills                      1.300000e+01      13.000000
# match_max_vehicleDestroysMinute                 7.429421e-04       0.000743
# match_max_killsMiter                            0.000000e+00       0.000000
# match_max_playersJoined                         9.500000e+01      95.000000
# match_max_killsNorm                             3.500000e-01       0.350000
# match_max_damageDealtNorm                       4.918500e+01      49.185001
# match_max_boostsPerWalkDistance                 2.759890e-02       0.027599
# match_max_healsPerWalkDistance                  4.599816e-02       0.045998
# match_max_healsAndBoosts                        1.600000e+01      16.000000
# match_max_healsAndBoostsPerWalkDistance         7.359706e-02       0.073597
# match_min_assists                               0.000000e+00       0.000000
# match_min_boosts                                0.000000e+00       0.000000
# match_min_damageDealt                           0.000000e+00       0.000000
# match_min_DBNOs                                 0.000000e+00       0.000000
# match_min_headshotKills                         0.000000e+00       0.000000
# match_min_heals                                 0.000000e+00       0.000000
# match_min_killPlace                             1.000000e+00       1.000000
# match_min_killPoints                            1.000000e+03    1000.000000
# match_min_kills                                 0.000000e+00       0.000000
# match_min_killStreaks                           0.000000e+00       0.000000
# match_min_longestKill                           0.000000e+00       0.000000
# match_min_matchDuration                         1.346000e+03    1346.000000
# match_min_rankPoints                            0.000000e+00       0.000000
# match_min_revives                               0.000000e+00       0.000000
# match_min_rideDistance                          0.000000e+00       0.000000
# match_min_roadKills                             0.000000e+00       0.000000
# match_min_swimDistance                          0.000000e+00       0.000000
# match_min_teamKills                             0.000000e+00       0.000000
# match_min_vehicleDestroys                       0.000000e+00       0.000000
# match_min_walkDistance                          0.000000e+00       0.000000
# match_min_weaponsAcquired                       0.000000e+00       0.000000
# match_min_winPoints                             1.399000e+03    1399.000000
# match_min_headshot_percentage                   0.000000e+00       0.000000
# match_min_totalDistance                         0.000000e+00       0.000000
# match_min_health_items                          0.000000e+00       0.000000
# match_min_killPlaceOverMaxPlace                 3.571429e-02       0.035714
# match_min_killsOverWalkDistance                 0.000000e+00       0.000000
# match_min_killStreakRate                        0.000000e+00       0.000000
# match_min_killMinute                            0.000000e+00       0.000000
# match_min_damageDealtMinute                     0.000000e+00       0.000000
# match_min_participateKills                      0.000000e+00       0.000000
# match_min_vehicleDestroysMinute                 0.000000e+00       0.000000
# match_min_killsMiter                            0.000000e+00       0.000000
# match_min_playersJoined                         9.500000e+01      95.000000
# match_min_killsNorm                             0.000000e+00       0.000000
# match_min_damageDealtNorm                       0.000000e+00       0.000000
# match_min_boostsPerWalkDistance                 0.000000e+00       0.000000
# match_min_healsPerWalkDistance                  0.000000e+00       0.000000
# match_min_healsAndBoosts                        0.000000e+00       0.000000
# match_min_healsAndBoostsPerWalkDistance         0.000000e+00       0.000000
# match_mean_assists                              3.578947e-01       0.357895
# match_mean_boosts                               1.242105e+00       1.242105
# match_mean_damageDealt                          1.425239e+02     142.523911
# match_mean_DBNOs                                8.421053e-01       0.842105
# match_mean_headshotKills                        1.789474e-01       0.178947
# match_mean_heals                                1.115789e+00       1.115789
# match_mean_killPlace                            4.800000e+01      48.000000
# match_mean_killPoints                           1.321547e+03    1321.547368
# match_mean_kills                                9.473684e-01       0.947368
# match_mean_killStreaks                          5.473684e-01       0.547368
# match_mean_longestKill                          1.978105e+01      19.781052
# match_mean_matchDuration                        1.346000e+03    1346.000000
# match_mean_rankPoints                           0.000000e+00       0.000000
# match_mean_revives                              1.578947e-01       0.157895
# match_mean_rideDistance                         9.263123e+01      92.631226
# match_mean_roadKills                            0.000000e+00       0.000000
# match_mean_swimDistance                         3.761548e+00       3.761548
# match_mean_teamKills                            1.052632e-02       0.010526
# match_mean_vehicleDestroys                      2.105263e-02       0.021053
# match_mean_walkDistance                         1.253503e+03    1253.503052
# match_mean_weaponsAcquired                      3.073684e+00       3.073684
# match_mean_winPoints                            1.490632e+03    1490.631579
# match_mean_headshot_percentage                  7.315789e-02       0.073158
# match_mean_totalDistance                        1.349896e+03    1349.895752
# match_mean_health_items                         2.357895e+00       2.357895
# match_mean_killPlaceOverMaxPlace                1.714286e+00       1.714286
# match_mean_killsOverWalkDistance                1.412633e-03       0.001413
# match_mean_killStreakRate                       2.690727e-01       0.269073
# match_mean_killMinute                           7.038398e-04       0.000704
# match_mean_damageDealtMinute                    1.058870e-01       0.105887
# match_mean_participateKills                     2.147368e+00       2.147368
# match_mean_vehicleDestroysMinute                1.564089e-05       0.000016
# match_mean_killsMiter                           0.000000e+00       0.000000
# match_mean_playersJoined                        9.500000e+01      95.000000
# match_mean_killsNorm                            4.736842e-02       0.047368
# match_mean_damageDealtNorm                      7.126195e+00       7.126195
# match_mean_boostsPerWalkDistance                1.100960e-03       0.001101
# match_mean_healsPerWalkDistance                 1.299162e-03       0.001299
# match_mean_healsAndBoosts                       2.357895e+00       2.357895
# match_mean_healsAndBoostsPerWalkDistance        2.400122e-03       0.002400
#
#                                                            4
# Id                                              3.443301e+06
# groupId                                         1.467243e+06
# matchId                                         1.000000e+00
# assists                                         0.000000e+00
# boosts                                          0.000000e+00
# damageDealt                                     0.000000e+00
# DBNOs                                           0.000000e+00
# headshotKills                                   0.000000e+00
# heals                                           0.000000e+00
# killPlace                                       3.900000e+01
# killPoints                                      1.163000e+03
# kills                                           0.000000e+00
# killStreaks                                     0.000000e+00
# longestKill                                     0.000000e+00
# matchDuration                                   1.346000e+03
# matchType                                       3.000000e+00
# maxPlace                                        2.800000e+01
# numGroups                                       2.800000e+01
# rankPoints                                      0.000000e+00
# revives                                         0.000000e+00
# rideDistance                                    0.000000e+00
# roadKills                                       0.000000e+00
# swimDistance                                    0.000000e+00
# teamKills                                       0.000000e+00
# vehicleDestroys                                 0.000000e+00
# walkDistance                                    1.402000e+03
# weaponsAcquired                                 5.000000e+00
# winPoints                                       1.521000e+03
# headshot_percentage                             0.000000e+00
# totalDistance                                   1.402000e+03
# health_items                                    0.000000e+00
# killPlaceOverMaxPlace                           1.392857e+00
# killsOverWalkDistance                           0.000000e+00
# killStreakRate                                  0.000000e+00
# killMinute                                      0.000000e+00
# damageDealtMinute                               0.000000e+00
# participateKills                                0.000000e+00
# vehicleDestroysMinute                           0.000000e+00
# killsMiter                                      0.000000e+00
# playersJoined                                   9.500000e+01
# killsNorm                                       0.000000e+00
# damageDealtNorm                                 0.000000e+00
# boostsPerWalkDistance                           0.000000e+00
# healsPerWalkDistance                            0.000000e+00
# healsAndBoosts                                  0.000000e+00
# healsAndBoostsPerWalkDistance                   0.000000e+00
# percentage_match_assists                        3.842105e-01
# percentage_match_boosts                         2.684211e-01
# percentage_match_damageDealt                    1.421053e-01
# percentage_match_DBNOs                          3.000000e-01
# percentage_match_headshotKills                  4.263158e-01
# percentage_match_heals                          3.052632e-01
# percentage_match_killPlace                      4.105263e-01
# percentage_match_killPoints                     2.000000e-01
# percentage_match_kills                          3.210526e-01
# percentage_match_killStreaks                    3.210526e-01
# percentage_match_longestKill                    3.210526e-01
# percentage_match_matchDuration                  5.052632e-01
# percentage_match_rankPoints                     5.052632e-01
# percentage_match_revives                        4.315789e-01
# percentage_match_rideDistance                   4.105263e-01
# percentage_match_roadKills                      5.052632e-01
# percentage_match_swimDistance                   4.421053e-01
# percentage_match_teamKills                      5.000000e-01
# percentage_match_vehicleDestroys                4.947368e-01
# percentage_match_walkDistance                   5.578947e-01
# percentage_match_weaponsAcquired                8.526316e-01
# percentage_match_winPoints                      8.210526e-01
# percentage_match_headshot_percentage            4.263158e-01
# percentage_match_totalDistance                  5.578947e-01
# percentage_match_health_items                   2.368421e-01
# percentage_match_killPlaceOverMaxPlace          4.105263e-01
# percentage_match_killsOverWalkDistance          3.210526e-01
# percentage_match_killStreakRate                 3.210526e-01
# percentage_match_killMinute                     3.210526e-01
# percentage_match_damageDealtMinute              1.421053e-01
# percentage_match_participateKills               2.473684e-01
# percentage_match_vehicleDestroysMinute          4.947368e-01
# percentage_match_killsMiter                     5.052632e-01
# percentage_match_playersJoined                  5.052632e-01
# percentage_match_killsNorm                      3.210526e-01
# percentage_match_damageDealtNorm                1.421053e-01
# percentage_match_boostsPerWalkDistance          2.684211e-01
# percentage_match_healsPerWalkDistance           3.052632e-01
# percentage_match_healsAndBoosts                 2.368421e-01
# percentage_match_healsAndBoostsPerWalkDistance  2.368421e-01
# match_max_assists                               4.000000e+00
# match_max_boosts                                8.000000e+00
# match_max_damageDealt                           9.837000e+02
# match_max_DBNOs                                 4.000000e+00
# match_max_headshotKills                         2.000000e+00
# match_max_heals                                 9.000000e+00
# match_max_killPlace                             9.500000e+01
# match_max_killPoints                            1.862000e+03
# match_max_kills                                 7.000000e+00
# match_max_killStreaks                           4.000000e+00
# match_max_longestKill                           1.925000e+02
# match_max_matchDuration                         1.346000e+03
# match_max_rankPoints                            0.000000e+00
# match_max_revives                               2.000000e+00
# match_max_rideDistance                          2.202000e+03
# match_max_roadKills                             0.000000e+00
# match_max_swimDistance                          1.416000e+02
# match_max_teamKills                             1.000000e+00
# match_max_vehicleDestroys                       1.000000e+00
# match_max_walkDistance                          3.438000e+03
# match_max_weaponsAcquired                       1.200000e+01
# match_max_winPoints                             1.679000e+03
# match_max_headshot_percentage                   1.000000e+00
# match_max_totalDistance                         4.602000e+03
# match_max_health_items                          1.600000e+01
# match_max_killPlaceOverMaxPlace                 3.392857e+00
# match_max_killsOverWalkDistance                 2.703799e-02
# match_max_killStreakRate                        1.000000e+00
# match_max_killMinute                            5.200594e-03
# match_max_damageDealtMinute                     7.308321e-01
# match_max_participateKills                      1.300000e+01
# match_max_vehicleDestroysMinute                 7.429421e-04
# match_max_killsMiter                            0.000000e+00
# match_max_playersJoined                         9.500000e+01
# match_max_killsNorm                             3.500000e-01
# match_max_damageDealtNorm                       4.918500e+01
# match_max_boostsPerWalkDistance                 2.759890e-02
# match_max_healsPerWalkDistance                  4.599816e-02
# match_max_healsAndBoosts                        1.600000e+01
# match_max_healsAndBoostsPerWalkDistance         7.359706e-02
# match_min_assists                               0.000000e+00
# match_min_boosts                                0.000000e+00
# match_min_damageDealt                           0.000000e+00
# match_min_DBNOs                                 0.000000e+00
# match_min_headshotKills                         0.000000e+00
# match_min_heals                                 0.000000e+00
# match_min_killPlace                             1.000000e+00
# match_min_killPoints                            1.000000e+03
# match_min_kills                                 0.000000e+00
# match_min_killStreaks                           0.000000e+00
# match_min_longestKill                           0.000000e+00
# match_min_matchDuration                         1.346000e+03
# match_min_rankPoints                            0.000000e+00
# match_min_revives                               0.000000e+00
# match_min_rideDistance                          0.000000e+00
# match_min_roadKills                             0.000000e+00
# match_min_swimDistance                          0.000000e+00
# match_min_teamKills                             0.000000e+00
# match_min_vehicleDestroys                       0.000000e+00
# match_min_walkDistance                          0.000000e+00
# match_min_weaponsAcquired                       0.000000e+00
# match_min_winPoints                             1.399000e+03
# match_min_headshot_percentage                   0.000000e+00
# match_min_totalDistance                         0.000000e+00
# match_min_health_items                          0.000000e+00
# match_min_killPlaceOverMaxPlace                 3.571429e-02
# match_min_killsOverWalkDistance                 0.000000e+00
# match_min_killStreakRate                        0.000000e+00
# match_min_killMinute                            0.000000e+00
# match_min_damageDealtMinute                     0.000000e+00
# match_min_participateKills                      0.000000e+00
# match_min_vehicleDestroysMinute                 0.000000e+00
# match_min_killsMiter                            0.000000e+00
# match_min_playersJoined                         9.500000e+01
# match_min_killsNorm                             0.000000e+00
# match_min_damageDealtNorm                       0.000000e+00
# match_min_boostsPerWalkDistance                 0.000000e+00
# match_min_healsPerWalkDistance                  0.000000e+00
# match_min_healsAndBoosts                        0.000000e+00
# match_min_healsAndBoostsPerWalkDistance         0.000000e+00
# match_mean_assists                              3.578947e-01
# match_mean_boosts                               1.242105e+00
# match_mean_damageDealt                          1.425239e+02
# match_mean_DBNOs                                8.421053e-01
# match_mean_headshotKills                        1.789474e-01
# match_mean_heals                                1.115789e+00
# match_mean_killPlace                            4.800000e+01
# match_mean_killPoints                           1.321547e+03
# match_mean_kills                                9.473684e-01
# match_mean_killStreaks                          5.473684e-01
# match_mean_longestKill                          1.978105e+01
# match_mean_matchDuration                        1.346000e+03
# match_mean_rankPoints                           0.000000e+00
# match_mean_revives                              1.578947e-01
# match_mean_rideDistance                         9.263123e+01
# match_mean_roadKills                            0.000000e+00
# match_mean_swimDistance                         3.761548e+00
# match_mean_teamKills                            1.052632e-02
# match_mean_vehicleDestroys                      2.105263e-02
# match_mean_walkDistance                         1.253503e+03
# match_mean_weaponsAcquired                      3.073684e+00
# match_mean_winPoints                            1.490632e+03
# match_mean_headshot_percentage                  7.315789e-02
# match_mean_totalDistance                        1.349896e+03
# match_mean_health_items                         2.357895e+00
# match_mean_killPlaceOverMaxPlace                1.714286e+00
# match_mean_killsOverWalkDistance                1.412633e-03
# match_mean_killStreakRate                       2.690727e-01
# match_mean_killMinute                           7.038398e-04
# match_mean_damageDealtMinute                    1.058870e-01
# match_mean_participateKills                     2.147368e+00
# match_mean_vehicleDestroysMinute                1.564089e-05
# match_mean_killsMiter                           0.000000e+00
# match_mean_playersJoined                        9.500000e+01
# match_mean_killsNorm                            4.736842e-02
# match_mean_damageDealtNorm                      7.126195e+00
# match_mean_boostsPerWalkDistance                1.100960e-03
# match_mean_healsPerWalkDistance                 1.299162e-03
# match_mean_healsAndBoosts                       2.357895e+00
# match_mean_healsAndBoostsPerWalkDistance        2.400122e-03

# %%
features = list(X_train.columns)
features.remove('matchId')
features.remove('groupId')
features.remove('Id')
features
# Out:
# ['assists',
#  'boosts',
#  'damageDealt',
#  'DBNOs',
#  'headshotKills',
#  'heals',
#  'killPlace',
#  'killPoints',
#  'kills',
#  'killStreaks',
#  'longestKill',
#  'matchDuration',
#  'matchType',
#  'maxPlace',
#  'numGroups',
#  'rankPoints',
#  'revives',
#  'rideDistance',
#  'roadKills',
#  'swimDistance',
#  'teamKills',
#  'vehicleDestroys',
#  'walkDistance',
#  'weaponsAcquired',
#  'winPoints',
#  'headshot_percentage',
#  'totalDistance',
#  'health_items',
#  'killPlaceOverMaxPlace',
#  'killsOverWalkDistance',
#  'killStreakRate',
#  'killMinute',
#  'damageDealtMinute',
#  'participateKills',
#  'vehicleDestroysMinute',
#  'killsMiter',
#  'playersJoined',
#  'killsNorm',
#  'damageDealtNorm',
#  'boostsPerWalkDistance',
#  'healsPerWalkDistance',
#  'healsAndBoosts',
#  'healsAndBoostsPerWalkDistance',
#  'percentage_match_assists',
#  'percentage_match_boosts',
#  'percentage_match_damageDealt',
#  'percentage_match_DBNOs',
#  'percentage_match_headshotKills',
#  'percentage_match_heals',
#  'percentage_match_killPlace',
#  'percentage_match_killPoints',
#  'percentage_match_kills',
#  'percentage_match_killStreaks',
#  'percentage_match_longestKill',
#  'percentage_match_matchDuration',
#  'percentage_match_rankPoints',
#  'percentage_match_revives',
#  'percentage_match_rideDistance',
#  'percentage_match_roadKills',
#  'percentage_match_swimDistance',
#  'percentage_match_teamKills',
#  'percentage_match_vehicleDestroys',
#  'percentage_match_walkDistance',
#  'percentage_match_weaponsAcquired',
#  'percentage_match_winPoints',
#  'percentage_match_headshot_percentage',
#  'percentage_match_totalDistance',
#  'percentage_match_health_items',
#  'percentage_match_killPlaceOverMaxPlace',
#  'percentage_match_killsOverWalkDistance',
#  'percentage_match_killStreakRate',
#  'percentage_match_killMinute',
#  'percentage_match_damageDealtMinute',
#  'percentage_match_participateKills',
#  'percentage_match_vehicleDestroysMinute',
#  'percentage_match_killsMiter',
#  'percentage_match_playersJoined',
#  'percentage_match_killsNorm',
#  'percentage_match_damageDealtNorm',
#  'percentage_match_boostsPerWalkDistance',
#  'percentage_match_healsPerWalkDistance',
#  'percentage_match_healsAndBoosts',
#  'percentage_match_healsAndBoostsPerWalkDistance',
#  'match_max_assists',
#  'match_max_boosts',
#  'match_max_damageDealt',
#  'match_max_DBNOs',
#  'match_max_headshotKills',
#  'match_max_heals',
#  'match_max_killPlace',
#  'match_max_killPoints',
#  'match_max_kills',
#  'match_max_killStreaks',
#  'match_max_longestKill',
#  'match_max_matchDuration',
#  'match_max_rankPoints',
#  'match_max_revives',
#  'match_max_rideDistance',
#  'match_max_roadKills',
#  'match_max_swimDistance',
#  'match_max_teamKills',
#  'match_max_vehicleDestroys',
#  'match_max_walkDistance',
#  'match_max_weaponsAcquired',
#  'match_max_winPoints',
#  'match_max_headshot_percentage',
#  'match_max_totalDistance',
#  'match_max_health_items',
#  'match_max_killPlaceOverMaxPlace',
#  'match_max_killsOverWalkDistance',
#  'match_max_killStreakRate',
#  'match_max_killMinute',
#  'match_max_damageDealtMinute',
#  'match_max_participateKills',
#  'match_max_vehicleDestroysMinute',
#  'match_max_killsMiter',
#  'match_max_playersJoined',
#  'match_max_killsNorm',
#  'match_max_damageDealtNorm',
#  'match_max_boostsPerWalkDistance',
#  'match_max_healsPerWalkDistance',
#  'match_max_healsAndBoosts',
#  'match_max_healsAndBoostsPerWalkDistance',
#  'match_min_assists',
#  'match_min_boosts',
#  'match_min_damageDealt',
#  'match_min_DBNOs',
#  'match_min_headshotKills',
#  'match_min_heals',
#  'match_min_killPlace',
#  'match_min_killPoints',
#  'match_min_kills',
#  'match_min_killStreaks',
#  'match_min_longestKill',
#  'match_min_matchDuration',
#  'match_min_rankPoints',
#  'match_min_revives',
#  'match_min_rideDistance',
#  'match_min_roadKills',
#  'match_min_swimDistance',
#  'match_min_teamKills',
#  'match_min_vehicleDestroys',
#  'match_min_walkDistance',
#  'match_min_weaponsAcquired',
#  'match_min_winPoints',
#  'match_min_headshot_percentage',
#  'match_min_totalDistance',
#  'match_min_health_items',
#  'match_min_killPlaceOverMaxPlace',
#  'match_min_killsOverWalkDistance',
#  'match_min_killStreakRate',
#  'match_min_killMinute',
#  'match_min_damageDealtMinute',
#  'match_min_participateKills',
#  'match_min_vehicleDestroysMinute',
#  'match_min_killsMiter',
#  'match_min_playersJoined',
#  'match_min_killsNorm',
#  'match_min_damageDealtNorm',
#  'match_min_boostsPerWalkDistance',
#  'match_min_healsPerWalkDistance',
#  'match_min_healsAndBoosts',
#  'match_min_healsAndBoostsPerWalkDistance',
#  'match_mean_assists',
#  'match_mean_boosts',
#  'match_mean_damageDealt',
#  'match_mean_DBNOs',
#  'match_mean_headshotKills',
#  'match_mean_heals',
#  'match_mean_killPlace',
#  'match_mean_killPoints',
#  'match_mean_kills',
#  'match_mean_killStreaks',
#  'match_mean_longestKill',
#  'match_mean_matchDuration',
#  'match_mean_rankPoints',
#  'match_mean_revives',
#  'match_mean_rideDistance',
#  'match_mean_roadKills',
#  'match_mean_swimDistance',
#  'match_mean_teamKills',
#  'match_mean_vehicleDestroys',
#  'match_mean_walkDistance',
#  'match_mean_weaponsAcquired',
#  'match_mean_winPoints',
#  'match_mean_headshot_percentage',
#  'match_mean_totalDistance',
#  'match_mean_health_items',
#  'match_mean_killPlaceOverMaxPlace',
#  'match_mean_killsOverWalkDistance',
#  'match_mean_killStreakRate',
#  'match_mean_killMinute',
#  'match_mean_damageDealtMinute',
#  'match_mean_participateKills',
#  'match_mean_vehicleDestroysMinute',
#  'match_mean_killsMiter',
#  'match_mean_playersJoined',
#  'match_mean_killsNorm',
#  'match_mean_damageDealtNorm',
#  'match_mean_boostsPerWalkDistance',
#  'match_mean_healsPerWalkDistance',
#  'match_mean_healsAndBoosts',
#  'match_mean_healsAndBoostsPerWalkDistance']

# %%
# Chooses random set for each tree. Helpful in reducing overfitting as it increases variance per each treee 
set_rf_samples(100000)

# %%
m = RandomForestRegressor(n_jobs=-1, n_estimators=40, max_features=0.5,min_samples_leaf=3)
m.fit(X_train[features], y_train)
print_score(m)
# Out:
# [0.06465375834107372, 0.12505719561699633, 0.9557858246561959, 0.834483841285198]

# %%
fi = rf_feat_importance(m, X_train[features]); 
display_all(fi)
# Out:
#                                                cols           imp
# 62                    percentage_match_walkDistance  3.639747e-01
# 66                   percentage_match_totalDistance  2.347459e-01
# 49                       percentage_match_killPlace  1.194464e-01
# 68           percentage_match_killPlaceOverMaxPlace  6.368488e-02
# 22                                     walkDistance  6.223488e-02
# 26                                    totalDistance  4.662379e-02
# 6                                         killPlace  1.207227e-02
# 69           percentage_match_killsOverWalkDistance  8.561481e-03
# 28                            killPlaceOverMaxPlace  6.064572e-03
# 51                           percentage_match_kills  5.402709e-03
# 71                      percentage_match_killMinute  5.376776e-03
# 70                  percentage_match_killStreakRate  4.036585e-03
# 30                                   killStreakRate  3.706612e-03
# 29                            killsOverWalkDistance  2.949841e-03
# 52                     percentage_match_killStreaks  2.682232e-03
# 44                          percentage_match_boosts  2.678167e-03
# 53                     percentage_match_longestKill  1.901415e-03
# 77                       percentage_match_killsNorm  1.855702e-03
# 190                       match_mean_killStreakRate  1.630416e-03
# 63                 percentage_match_weaponsAcquired  1.278197e-03
# 1                                            boosts  1.237449e-03
# 14                                        numGroups  1.168553e-03
# 43                         percentage_match_assists  1.044109e-03
# 189                match_mean_killsOverWalkDistance  9.578305e-04
# 171                                match_mean_kills  7.853112e-04
# 46                           percentage_match_DBNOs  7.585941e-04
# 172                          match_mean_killStreaks  7.093084e-04
# 182                         match_mean_walkDistance  7.004748e-04
# 165                          match_mean_damageDealt  6.706501e-04
# 73                percentage_match_participateKills  6.441063e-04
# 188                match_mean_killPlaceOverMaxPlace  6.383961e-04
# 108                 match_max_killPlaceOverMaxPlace  6.358287e-04
# 67                    percentage_match_health_items  6.222547e-04
# 81                  percentage_match_healsAndBoosts  6.201719e-04
# 109                 match_max_killsOverWalkDistance  6.115951e-04
# 173                          match_mean_longestKill  6.011455e-04
# 57                    percentage_match_rideDistance  5.998592e-04
# 93                            match_max_longestKill  5.923368e-04
# 56                         percentage_match_revives  5.906413e-04
# 193                     match_mean_participateKills  5.896756e-04
# 102                          match_max_walkDistance  5.878394e-04
# 166                                match_mean_DBNOs  5.740145e-04
# 163                              match_mean_assists  5.728245e-04
# 119                 match_max_boostsPerWalkDistance  5.711602e-04
# 185                  match_mean_headshot_percentage  5.412850e-04
# 167                        match_mean_headshotKills  5.393756e-04
# 85                            match_max_damageDealt  5.354573e-04
# 183                      match_mean_weaponsAcquired  5.312968e-04
# 111                            match_max_killMinute  5.308222e-04
# 192                    match_mean_damageDealtMinute  5.261937e-04
# 199                match_mean_boostsPerWalkDistance  5.257227e-04
# 10                                      longestKill  5.228889e-04
# 164                               match_mean_boosts  5.201909e-04
# 79           percentage_match_boostsPerWalkDistance  5.114143e-04
# 31                                       killMinute  5.057939e-04
# 191                           match_mean_killMinute  4.976025e-04
# 55                      percentage_match_rankPoints  4.956085e-04
# 120                  match_max_healsPerWalkDistance  4.875776e-04
# 186                        match_mean_totalDistance  4.852499e-04
# 112                     match_max_damageDealtMinute  4.813930e-04
# 122         match_max_healsAndBoostsPerWalkDistance  4.764187e-04
# 59                    percentage_match_swimDistance  4.745177e-04
# 202        match_mean_healsAndBoostsPerWalkDistance  4.681745e-04
# 200                 match_mean_healsPerWalkDistance  4.541554e-04
# 118                       match_max_damageDealtNorm  4.426522e-04
# 48                           percentage_match_heals  4.326544e-04
# 99                           match_max_swimDistance  4.316106e-04
# 106                         match_max_totalDistance  4.190797e-04
# 179                         match_mean_swimDistance  4.178230e-04
# 176                              match_mean_revives  4.164096e-04
# 97                           match_max_rideDistance  4.144942e-04
# 64                       percentage_match_winPoints  4.094241e-04
# 47                   percentage_match_headshotKills  4.068461e-04
# 177                         match_mean_rideDistance  4.049493e-04
# 38                                  damageDealtNorm  4.043893e-04
# 82   percentage_match_healsAndBoostsPerWalkDistance  4.027443e-04
# 65             percentage_match_headshot_percentage  4.010043e-04
# 80            percentage_match_healsPerWalkDistance  3.931679e-04
# 32                                damageDealtMinute  3.923907e-04
# 148                 match_min_killPlaceOverMaxPlace  3.747145e-04
# 17                                     rideDistance  3.725570e-04
# 168                                match_mean_heals  3.719498e-04
# 180                            match_mean_teamKills  3.682422e-04
# 198                      match_mean_damageDealtNorm  3.633689e-04
# 39                            boostsPerWalkDistance  3.461152e-04
# 60                       percentage_match_teamKills  3.451874e-04
# 50                      percentage_match_killPoints  3.450486e-04
# 13                                         maxPlace  3.410519e-04
# 201                       match_mean_healsAndBoosts  3.328996e-04
# 2                                       damageDealt  3.227741e-04
# 187                         match_mean_health_items  3.159775e-04
# 15                                       rankPoints  3.102242e-04
# 23                                  weaponsAcquired  3.024533e-04
# 95                             match_max_rankPoints  2.922357e-04
# 78                 percentage_match_damageDealtNorm  2.849401e-04
# 117                             match_max_killsNorm  2.848231e-04
# 135                            match_min_rankPoints  2.805351e-04
# 113                      match_max_participateKills  2.769899e-04
# 72               percentage_match_damageDealtMinute  2.762437e-04
# 197                            match_mean_killsNorm  2.759045e-04
# 175                           match_mean_rankPoints  2.736422e-04
# 88                                  match_max_heals  2.710285e-04
# 45                     percentage_match_damageDealt  2.661608e-04
# 42                    healsAndBoostsPerWalkDistance  2.632560e-04
# 103                       match_max_weaponsAcquired  2.400958e-04
# 134                         match_min_matchDuration  2.340597e-04
# 107                          match_max_health_items  2.301217e-04
# 121                        match_max_healsAndBoosts  2.268422e-04
# 84                                 match_max_boosts  2.248565e-04
# 114                 match_max_vehicleDestroysMinute  2.202439e-04
# 174                        match_mean_matchDuration  2.188013e-04
# 41                                   healsAndBoosts  2.117775e-04
# 11                                    matchDuration  2.052579e-04
# 61                 percentage_match_vehicleDestroys  1.971116e-04
# 24                                        winPoints  1.961044e-04
# 74           percentage_match_vehicleDestroysMinute  1.928389e-04
# 40                             healsPerWalkDistance  1.906236e-04
# 94                          match_max_matchDuration  1.898118e-04
# 86                                  match_max_DBNOs  1.871293e-04
# 146                         match_min_totalDistance  1.791978e-04
# 91                                  match_max_kills  1.711610e-04
# 37                                        killsNorm  1.709739e-04
# 194                match_mean_vehicleDestroysMinute  1.701870e-04
# 142                          match_min_walkDistance  1.676984e-04
# 75                      percentage_match_killsMiter  1.652726e-04
# 27                                     health_items  1.648775e-04
# 90                             match_max_killPoints  1.599271e-04
# 104                             match_max_winPoints  1.577665e-04
# 144                             match_min_winPoints  1.576137e-04
# 170                           match_mean_killPoints  1.558309e-04
# 181                      match_mean_vehicleDestroys  1.524348e-04
# 7                                        killPoints  1.506393e-04
# 58                       percentage_match_roadKills  1.500576e-04
# 87                          match_max_headshotKills  1.472246e-04
# 184                            match_mean_winPoints  1.431309e-04
# 83                                match_max_assists  1.287355e-04
# 92                            match_max_killStreaks  1.216485e-04
# 130                            match_min_killPoints  1.143870e-04
# 33                                 participateKills  1.089487e-04
# 0                                           assists  1.088869e-04
# 8                                             kills  1.048309e-04
# 96                                match_max_revives  1.025574e-04
# 3                                             DBNOs  7.927228e-05
# 76                   percentage_match_playersJoined  7.641563e-05
# 178                            match_mean_roadKills  7.465494e-05
# 115                            match_max_killsMiter  7.360360e-05
# 105                   match_max_headshot_percentage  7.070438e-05
# 195                           match_mean_killsMiter  7.053616e-05
# 156                         match_min_playersJoined  6.721071e-05
# 12                                        matchType  6.706776e-05
# 5                                             heals  6.387105e-05
# 116                         match_max_playersJoined  6.349079e-05
# 169                            match_mean_killPlace  6.096565e-05
# 89                              match_max_killPlace  6.072357e-05
# 36                                    playersJoined  6.014180e-05
# 100                             match_max_teamKills  5.819960e-05
# 196                        match_mean_playersJoined  5.486413e-05
# 25                              headshot_percentage  5.454511e-05
# 54                   percentage_match_matchDuration  4.412618e-05
# 143                       match_min_weaponsAcquired  3.660094e-05
# 16                                          revives  3.416373e-05
# 19                                     swimDistance  3.269161e-05
# 9                                       killStreaks  3.149330e-05
# 4                                     headshotKills  3.061377e-05
# 110                        match_max_killStreakRate  1.880340e-05
# 101                       match_max_vehicleDestroys  1.505140e-05
# 98                              match_max_roadKills  1.146776e-05
# 158                       match_min_damageDealtNorm  8.985389e-06
# 20                                        teamKills  4.925473e-06
# 35                                       killsMiter  1.842273e-06
# 21                                  vehicleDestroys  9.221272e-07
# 34                            vehicleDestroysMinute  7.561429e-07
# 152                     match_min_damageDealtMinute  5.342799e-07
# 157                             match_min_killsNorm  3.042623e-07
# 18                                        roadKills  0.000000e+00
# 140                             match_min_teamKills  0.000000e+00
# 123                               match_min_assists  0.000000e+00
# 155                            match_min_killsMiter  0.000000e+00
# 139                          match_min_swimDistance  0.000000e+00
# 138                             match_min_roadKills  0.000000e+00
# 145                   match_min_headshot_percentage  0.000000e+00
# 137                          match_min_rideDistance  0.000000e+00
# 147                          match_min_health_items  0.000000e+00
# 136                               match_min_revives  0.000000e+00
# 149                 match_min_killsOverWalkDistance  0.000000e+00
# 150                        match_min_killStreakRate  0.000000e+00
# 151                            match_min_killMinute  0.000000e+00
# 153                      match_min_participateKills  0.000000e+00
# 154                 match_min_vehicleDestroysMinute  0.000000e+00
# 159                 match_min_boostsPerWalkDistance  0.000000e+00
# 124                                match_min_boosts  0.000000e+00
# 160                  match_min_healsPerWalkDistance  0.000000e+00
# 161                        match_min_healsAndBoosts  0.000000e+00
# 162         match_min_healsAndBoostsPerWalkDistance  0.000000e+00
# 133                           match_min_longestKill  0.000000e+00
# 132                           match_min_killStreaks  0.000000e+00
# 131                                 match_min_kills  0.000000e+00
# 129                             match_min_killPlace  0.000000e+00
# 128                                 match_min_heals  0.000000e+00
# 127                         match_min_headshotKills  0.000000e+00
# 126                                 match_min_DBNOs  0.000000e+00
# 141                       match_min_vehicleDestroys  0.000000e+00
# 125                           match_min_damageDealt  0.000000e+00

# %%
plot_fi(fi[:30])

# %% [markdown]
# **Removing columns which are not at all important**

# %%
to_keep = fi[fi.imp > 0.0005].cols
len(to_keep)
# Out:
# 55

# %%
X_train = X_train[to_keep]
X_valid = X_valid[to_keep]

# %%
features = list(X_train.columns)

# %%
features
# Out:
# ['percentage_match_walkDistance',
#  'percentage_match_totalDistance',
#  'percentage_match_killPlace',
#  'percentage_match_killPlaceOverMaxPlace',
#  'walkDistance',
#  'totalDistance',
#  'killPlace',
#  'percentage_match_killsOverWalkDistance',
#  'killPlaceOverMaxPlace',
#  'percentage_match_kills',
#  'percentage_match_killMinute',
#  'percentage_match_killStreakRate',
#  'killStreakRate',
#  'killsOverWalkDistance',
#  'percentage_match_killStreaks',
#  'percentage_match_boosts',
#  'percentage_match_longestKill',
#  'percentage_match_killsNorm',
#  'match_mean_killStreakRate',
#  'percentage_match_weaponsAcquired',
#  'boosts',
#  'numGroups',
#  'percentage_match_assists',
#  'match_mean_killsOverWalkDistance',
#  'match_mean_kills',
#  'percentage_match_DBNOs',
#  'match_mean_killStreaks',
#  'match_mean_walkDistance',
#  'match_mean_damageDealt',
#  'percentage_match_participateKills',
#  'match_mean_killPlaceOverMaxPlace',
#  'match_max_killPlaceOverMaxPlace',
#  'percentage_match_health_items',
#  'percentage_match_healsAndBoosts',
#  'match_max_killsOverWalkDistance',
#  'match_mean_longestKill',
#  'percentage_match_rideDistance',
#  'match_max_longestKill',
#  'percentage_match_revives',
#  'match_mean_participateKills',
#  'match_max_walkDistance',
#  'match_mean_DBNOs',
#  'match_mean_assists',
#  'match_max_boostsPerWalkDistance',
#  'match_mean_headshot_percentage',
#  'match_mean_headshotKills',
#  'match_max_damageDealt',
#  'match_mean_weaponsAcquired',
#  'match_max_killMinute',
#  'match_mean_damageDealtMinute',
#  'match_mean_boostsPerWalkDistance',
#  'longestKill',
#  'match_mean_boosts',
#  'percentage_match_boostsPerWalkDistance',
#  'killMinute']

# %%
m = RandomForestRegressor(n_jobs=-1, n_estimators=40, max_features=0.5,min_samples_leaf=3)
m.fit(X_train[features], y_train)
print_score(m)
# Out:
# [0.06386426482367347, 0.13253588299467692, 0.9568590392830573, 0.8140954670481336]

# %%
m = RandomForestRegressor(n_jobs=-1, n_estimators=40, max_features=0.5,min_samples_leaf=10)
m.fit(X_train[features], y_train)
print_score(m)
# Out:
# [0.06738396428823666, 0.11875077108587632, 0.9519728193344634, 0.850756335402745]

# %%
m = RandomForestRegressor(n_jobs=-1, n_estimators=40, max_features=0.5,min_samples_leaf=25)
m.fit(X_train[features], y_train)
print_score(m)
# Out:
# [0.07110738325355749, 0.12946596832107846, 0.9465185255634752, 0.8226078997703938]

# %%
fi = rf_feat_importance(m, X_train[features]); 
display_all(fi)
# Out:
#                                       cols       imp
# 0            percentage_match_walkDistance  0.303375
# 1           percentage_match_totalDistance  0.211254
# 4                             walkDistance  0.196652
# 3   percentage_match_killPlaceOverMaxPlace  0.087731
# 2               percentage_match_killPlace  0.087082
# 5                            totalDistance  0.033287
# 6                                killPlace  0.020808
# 7   percentage_match_killsOverWalkDistance  0.009204
# 8                    killPlaceOverMaxPlace  0.005363
# 9                   percentage_match_kills  0.005080
# 10             percentage_match_killMinute  0.004907
# 11         percentage_match_killStreakRate  0.004857
# 12                          killStreakRate  0.003214
# 15                 percentage_match_boosts  0.003161
# 13                   killsOverWalkDistance  0.002798
# 14            percentage_match_killStreaks  0.002218
# 17              percentage_match_killsNorm  0.001972
# 20                                  boosts  0.001420
# 16            percentage_match_longestKill  0.001358
# 18               match_mean_killStreakRate  0.001219
# 21                               numGroups  0.001126
# 19        percentage_match_weaponsAcquired  0.000877
# 36           percentage_match_rideDistance  0.000675
# 22                percentage_match_assists  0.000632
# 23        match_mean_killsOverWalkDistance  0.000630
# 32           percentage_match_health_items  0.000598
# 27                 match_mean_walkDistance  0.000576
# 33         percentage_match_healsAndBoosts  0.000573
# 30        match_mean_killPlaceOverMaxPlace  0.000516
# 41                        match_mean_DBNOs  0.000477
# 31         match_max_killPlaceOverMaxPlace  0.000474
# 24                        match_mean_kills  0.000398
# 25                  percentage_match_DBNOs  0.000390
# 26                  match_mean_killStreaks  0.000389
# 54                              killMinute  0.000374
# 39             match_mean_participateKills  0.000358
# 29       percentage_match_participateKills  0.000290
# 49            match_mean_damageDealtMinute  0.000276
# 34         match_max_killsOverWalkDistance  0.000264
# 48                    match_max_killMinute  0.000258
# 40                  match_max_walkDistance  0.000249
# 47              match_mean_weaponsAcquired  0.000238
# 53  percentage_match_boostsPerWalkDistance  0.000223
# 52                       match_mean_boosts  0.000222
# 35                  match_mean_longestKill  0.000221
# 38                percentage_match_revives  0.000217
# 28                  match_mean_damageDealt  0.000212
# 51                             longestKill  0.000200
# 43         match_max_boostsPerWalkDistance  0.000180
# 42                      match_mean_assists  0.000172
# 45                match_mean_headshotKills  0.000170
# 37                   match_max_longestKill  0.000168
# 50        match_mean_boostsPerWalkDistance  0.000146
# 46                   match_max_damageDealt  0.000145
# 44          match_mean_headshot_percentage  0.000127

# %%
plot_fi(fi[:15])

# %% [markdown]
# **Removing some more features**

# %%
to_keep = fi[fi.imp > 0.0005].cols
len(to_keep)
# Out:
# 29

# %%
X_train = X_train[to_keep]
X_valid = X_valid[to_keep]

# %%
features = X_train.columns

# %%
m = RandomForestRegressor(n_jobs=-1, n_estimators=40, max_features=0.6,min_samples_leaf=3)
m.fit(X_train[features], y_train)
print_score(m)
# Out:
# [0.06365211793634654, 0.13716824213350504, 0.9571451780008586, 0.800872989480249]

# %% [markdown]
# # **Removing redundant features**
# Variable which have similar meaning makes it very hard to interpret the model. So here we try to remove such features with help of dendogram

# %%
from scipy.cluster import hierarchy as hc
import scipy
from matplotlib import pyplot as plt

# %%
corr = np.round(scipy.stats.spearmanr(X_train[features]).correlation, 4)
corr_condensed = hc.distance.squareform(1-corr)
z = hc.linkage(corr_condensed, method='average')
fig = plt.figure(figsize=(16,10))
dendrogram = hc.dendrogram(z, labels=X_train[features].columns, orientation='left', leaf_font_size=16)
plt.show()

# %%
def get_score(X_train, y_train, X_valid, y_valid) :
    m = RandomForestRegressor(n_jobs=-1, n_estimators=40, max_features=0.6,min_samples_leaf=3)
    m.fit(X_train, y_train)
    res = [rmse(m.predict(X_train), y_train), rmse(m.predict(X_valid), y_valid),
                m.score(X_train, y_train), m.score(X_valid, y_valid)]    
    return res

# %% [markdown]
# **Let's try removing some of these related features to see if the model can be simplified without impacting the accuracy.**

# %%
for c in ('percentage_match_killPlaceOverMaxPlace', 'percentage_match_killPlace','percentage_match_health_items', 'percentage_match_killMinute'):
    print(c, get_score(X_train.drop(c, axis=1), y_train, X_valid.drop(c, axis = 1), y_valid))
# Out:
# percentage_match_killPlaceOverMaxPlace [0.06406470155724756, 0.09820191971152213, 0.9565878202360746, 0.897938256462231]
# percentage_match_killPlace [0.06413774692294756, 0.22899473503916248, 0.95648876830076, 0.44502423007284964]
# percentage_match_health_items [0.06348008515117975, 0.13998348851343423, 0.9573765126955681, 0.7926153288345112]
# percentage_match_killMinute [0.06372103364783441, 0.12386022974912894, 0.9570523305217308, 0.8376371035560884]

# %% [markdown]
# **From the above results, we can safely remove percentage_match_killPlaceOverMaxPlace **

# %%
X_train = X_train.drop(['percentage_match_killPlaceOverMaxPlace'], axis = 1)
X_valid = X_valid.drop(['percentage_match_killPlaceOverMaxPlace'], axis = 1)

# %%
features = list(X_train.columns)

# %% [markdown]
# **Final feature importance interpretation**

# %%
m = RandomForestRegressor(n_jobs=-1, n_estimators=40, max_features=0.6,min_samples_leaf=3)
m.fit(X_train, y_train)
print_score(m)
# Out:
# [0.06400058021574273, 0.09897987203417613, 0.9566746778685105, 0.8963147918811013]

# %%
fi = rf_feat_importance(m, X_train[features]); 
display_all(fi)
# Out:
#                                       cols       imp
# 0            percentage_match_walkDistance  0.466610
# 1           percentage_match_totalDistance  0.212380
# 3               percentage_match_killPlace  0.120439
# 5                                killPlace  0.056079
# 4                            totalDistance  0.034280
# 2                             walkDistance  0.024959
# 7                    killPlaceOverMaxPlace  0.009475
# 6   percentage_match_killsOverWalkDistance  0.008321
# 9              percentage_match_killMinute  0.006346
# 8                   percentage_match_kills  0.006142
# 10         percentage_match_killStreakRate  0.005051
# 13                   killsOverWalkDistance  0.004284
# 12                 percentage_match_boosts  0.004019
# 14            percentage_match_killStreaks  0.003542
# 17            percentage_match_longestKill  0.003426
# 18               match_mean_killStreakRate  0.003310
# 11                          killStreakRate  0.003291
# 23        match_mean_killsOverWalkDistance  0.003070
# 15              percentage_match_killsNorm  0.002974
# 19                               numGroups  0.002970
# 20        percentage_match_weaponsAcquired  0.002954
# 22                percentage_match_assists  0.002775
# 25                 match_mean_walkDistance  0.002640
# 27        match_mean_killPlaceOverMaxPlace  0.002601
# 21           percentage_match_rideDistance  0.002349
# 26         percentage_match_healsAndBoosts  0.001971
# 24           percentage_match_health_items  0.001944
# 16                                  boosts  0.001798

# %%
plot_fi(fi[:15])
